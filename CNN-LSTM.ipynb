# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score, mean_absolute_error
from keras.callbacks import History
from keras.callbacks import Callback

# %%
df = pd.read_csv('./Processed_Dataset.csv')
df = df.drop('Unnamed: 0', axis=1)
df = df.drop(columns=['Xylene','Toluene','Benzene','NO','NO2'])
df['Datetime'] = pd.to_datetime(df['Datetime'])

df.head()
# Out:
#              Datetime  PM2.5    PM10    NOx    NH3   CO    SO2      O3  \
# 0 2017-11-24 17:00:00  60.50   98.00  18.25   8.50  0.1  11.85  126.40
# 1 2017-11-24 18:00:00  65.50  111.25  15.07   9.77  0.1  13.17  117.12
# 2 2017-11-24 19:00:00  80.00  132.00  15.15  12.02  0.1  12.08   98.98
# 3 2017-11-24 20:00:00  81.50  133.25  10.23  11.58  0.1  10.47  112.20
# 4 2017-11-24 21:00:00  75.25  116.00  10.43  12.03  0.1   9.12  106.35
#
#         AQI
# 0  95.59999
# 1  95.59999
# 2  95.59999
# 3  95.59999
# 4  95.59999

# %%
def create_sequence(data, timesteps):
    sequences = []
    for i in range(len(data) - timesteps + 1):
        sequences.append(data[i:i + timesteps])
    return np.array(sequences)

# %%
X = df.drop(columns=['AQI','Datetime'])
y = df['AQI']

# Hitung jumlah sampel untuk data latih (80%) dan data uji (20%)
train_size = int(0.8 * len(df))
test_size = len(df) - train_size

# Bagi data menjadi data latih dan data uji berdasarkan jumlah sampel yang dihitung
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Mengubah data menjadi urutan dengan panjang 24 timestep
X_train = create_sequence(X_train, 24)
X_test  = create_sequence(X_test, 24)

# Menyesuaikan panjang y_train dan y_test
y_train = y_train[-X_train.shape[0]:]
y_test  = y_test[-X_test.shape[0]:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18204, 24, 7)
# X_test shape: (4534, 24, 7)
# y_train shape: (18204,)
# y_test shape: (4534,)

# %%
# Callback untuk menyimpan R-squared dan MAE setiap epoch
class MetricsHistory(Callback):
    def on_train_begin(self, logs={}):
        self.r2_scores = []
        self.mae_scores = []

    def on_epoch_end(self, epoch, logs={}):
        X_val_lstm = X_test
        y_pred = self.model.predict(X_val_lstm)
        
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        
        self.r2_scores.append(r2)
        self.mae_scores.append(mae)
        
        print(f'Epoch {epoch+1} - MAE: {mae:.6f}')

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, LSTM
from sklearn.metrics import r2_score, mean_absolute_error

# Inisialisasi model Sequential
model_lstm = Sequential()

# Tambahkan lapisan LSTM dengan 50 unit dan input_shape=(1, jumlah_fitur)
model_lstm.add(Conv1D(64, kernel_size=3, input_shape=(X_train.shape[1], X_train.shape[-1])))
model_lstm.add(LSTM(64))

# Tambahkan lapisan Dense dengan 1 neuron (untuk output regresi)
model_lstm.add(Dense(1))

# Kompilasi model dengan mean squared error sebagai loss function dan optimizer adam
model_lstm.compile(optimizer='adam', loss='mean_absolute_error')

# Inisialisasi callback untuk menyimpan R-squared
callback = MetricsHistory()

# Latih model menggunakan data latih dengan callback R2History
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, callbacks=[callback])

# Prediksi menggunakan data uji
y_pred_lstm = model_lstm.predict(X_test)
# Out:
# Epoch 1/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 1 - MAE: 37.687915
# 285/285 - 7s - loss: 88.3044 - 7s/epoch - 25ms/step
# Epoch 2/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 2 - MAE: 23.462238
# 285/285 - 4s - loss: 69.6882 - 4s/epoch - 15ms/step
# Epoch 3/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 3 - MAE: 19.125925
# 285/285 - 4s - loss: 56.3986 - 4s/epoch - 14ms/step
# Epoch 4/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 4 - MAE: 15.164528
# 285/285 - 4s - loss: 47.1793 - 4s/epoch - 14ms/step
# Epoch 5/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 5 - MAE: 16.584241
# 285/285 - 4s - loss: 39.4152 - 4s/epoch - 15ms/step
# Epoch 6/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 6 - MAE: 14.212966
# 285/285 - 4s - loss: 33.0865 - 4s/epoch - 14ms/step
# Epoch 7/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 7 - MAE: 17.306595
# 285/285 - 4s - loss: 29.0948 - 4s/epoch - 15ms/step
# Epoch 8/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 8 - MAE: 10.400625
# 285/285 - 4s - loss: 27.2747 - 4s/epoch - 15ms/step
# Epoch 9/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 9 - MAE: 9.439804
# 285/285 - 4s - loss: 25.6625 - 4s/epoch - 15ms/step
# Epoch 10/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 10 - MAE: 9.060373
# 285/285 - 4s - loss: 24.0102 - 4s/epoch - 14ms/step
# Epoch 11/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 11 - MAE: 8.349134
# 285/285 - 4s - loss: 22.1187 - 4s/epoch - 15ms/step
# Epoch 12/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 12 - MAE: 8.352060
# 285/285 - 4s - loss: 20.8878 - 4s/epoch - 14ms/step
# Epoch 13/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 13 - MAE: 8.168769
# 285/285 - 4s - loss: 19.6453 - 4s/epoch - 15ms/step
# Epoch 14/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 14 - MAE: 9.424986
# 285/285 - 5s - loss: 18.2467 - 5s/epoch - 16ms/step
# Epoch 15/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 15 - MAE: 8.501187
# 285/285 - 5s - loss: 17.5298 - 5s/epoch - 16ms/step
# Epoch 16/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 16 - MAE: 9.980429
# 285/285 - 4s - loss: 17.1007 - 4s/epoch - 15ms/step
# Epoch 17/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 17 - MAE: 8.791718
# 285/285 - 4s - loss: 16.4678 - 4s/epoch - 15ms/step
# Epoch 18/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 18 - MAE: 7.954259
# 285/285 - 5s - loss: 14.9645 - 5s/epoch - 18ms/step
# Epoch 19/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 19 - MAE: 7.595551
# 285/285 - 5s - loss: 14.4140 - 5s/epoch - 19ms/step
# Epoch 20/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 20 - MAE: 7.770811
# 285/285 - 5s - loss: 13.9040 - 5s/epoch - 17ms/step
# Epoch 21/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 21 - MAE: 8.142997
# 285/285 - 5s - loss: 13.4665 - 5s/epoch - 17ms/step
# Epoch 22/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 22 - MAE: 8.256752
# 285/285 - 5s - loss: 12.5950 - 5s/epoch - 16ms/step
# Epoch 23/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 23 - MAE: 7.980098
# 285/285 - 5s - loss: 12.5444 - 5s/epoch - 16ms/step
# Epoch 24/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 24 - MAE: 7.504876
# 285/285 - 4s - loss: 12.4330 - 4s/epoch - 15ms/step
# Epoch 25/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 25 - MAE: 7.651630
# 285/285 - 5s - loss: 11.7715 - 5s/epoch - 16ms/step
# Epoch 26/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 26 - MAE: 7.201838
# 285/285 - 4s - loss: 11.4300 - 4s/epoch - 15ms/step
# Epoch 27/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 27 - MAE: 7.097731
# 285/285 - 4s - loss: 11.0429 - 4s/epoch - 15ms/step
# Epoch 28/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 28 - MAE: 7.182250
# 285/285 - 4s - loss: 10.7666 - 4s/epoch - 16ms/step
# Epoch 29/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 29 - MAE: 6.991331
# 285/285 - 4s - loss: 10.6648 - 4s/epoch - 16ms/step
# Epoch 30/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 30 - MAE: 7.049871
# 285/285 - 4s - loss: 10.2668 - 4s/epoch - 15ms/step
# Epoch 31/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 31 - MAE: 6.639306
# 285/285 - 4s - loss: 9.8374 - 4s/epoch - 15ms/step
# Epoch 32/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 32 - MAE: 7.221732
# 285/285 - 4s - loss: 9.4909 - 4s/epoch - 15ms/step
# Epoch 33/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 33 - MAE: 7.246254
# 285/285 - 4s - loss: 9.5010 - 4s/epoch - 15ms/step
# Epoch 34/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 34 - MAE: 7.797509
# 285/285 - 4s - loss: 9.3686 - 4s/epoch - 14ms/step
# Epoch 35/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 35 - MAE: 6.875746
# 285/285 - 4s - loss: 8.9245 - 4s/epoch - 14ms/step
# Epoch 36/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 36 - MAE: 6.957479
# 285/285 - 4s - loss: 9.1408 - 4s/epoch - 15ms/step
# Epoch 37/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 37 - MAE: 7.026650
# 285/285 - 5s - loss: 8.6272 - 5s/epoch - 16ms/step
# Epoch 38/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 38 - MAE: 6.637729
# 285/285 - 4s - loss: 8.5162 - 4s/epoch - 15ms/step
# Epoch 39/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 39 - MAE: 7.039799
# 285/285 - 4s - loss: 8.4362 - 4s/epoch - 15ms/step
# Epoch 40/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 40 - MAE: 6.968160
# 285/285 - 4s - loss: 8.2011 - 4s/epoch - 15ms/step
# Epoch 41/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 41 - MAE: 7.274221
# 285/285 - 4s - loss: 8.1070 - 4s/epoch - 15ms/step
# Epoch 42/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 42 - MAE: 6.967390
# 285/285 - 4s - loss: 7.9584 - 4s/epoch - 15ms/step
# Epoch 43/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 43 - MAE: 7.095029
# 285/285 - 4s - loss: 7.9819 - 4s/epoch - 15ms/step
# Epoch 44/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 44 - MAE: 7.391477
# 285/285 - 4s - loss: 7.6986 - 4s/epoch - 15ms/step
# Epoch 45/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 45 - MAE: 7.090251
# 285/285 - 4s - loss: 7.5907 - 4s/epoch - 14ms/step
# Epoch 46/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 46 - MAE: 6.621604
# 285/285 - 4s - loss: 7.5334 - 4s/epoch - 14ms/step
# Epoch 47/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 47 - MAE: 7.870022
# 285/285 - 4s - loss: 7.7141 - 4s/epoch - 14ms/step
# Epoch 48/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 48 - MAE: 6.910536
# 285/285 - 4s - loss: 7.7224 - 4s/epoch - 14ms/step
# Epoch 49/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 49 - MAE: 6.609043
# 285/285 - 4s - loss: 7.2868 - 4s/epoch - 14ms/step
# Epoch 50/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 50 - MAE: 6.836617
# 285/285 - 4s - loss: 7.3497 - 4s/epoch - 15ms/step
# 142/142 [==============================] - 1s 5ms/step

# %%
standardscalerdf = df
standardscalerdf['Datetime'] = pd.to_datetime(standardscalerdf['Datetime'])

datetime = standardscalerdf[['Datetime']]
aqi = standardscalerdf[['AQI']]

standardscalerdf = standardscalerdf.drop(columns=['Datetime','AQI'])

standardscalerdf.head()
# Out:
#    PM2.5    PM10    NOx    NH3   CO    SO2      O3
# 0  60.50   98.00  18.25   8.50  0.1  11.85  126.40
# 1  65.50  111.25  15.07   9.77  0.1  13.17  117.12
# 2  80.00  132.00  15.15  12.02  0.1  12.08   98.98
# 3  81.50  133.25  10.23  11.58  0.1  10.47  112.20
# 4  75.25  116.00  10.43  12.03  0.1   9.12  106.35

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_data = scaler.fit_transform(standardscalerdf)

# Konversi scaled_data kembali menjadi DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=standardscalerdf.columns)

# Gabungkan scaled_df dengan date_column
result_df = pd.concat([datetime, scaled_df, aqi], axis=1)

standardscalerdf = result_df

standardscalerdf.head()
# Out:
#              Datetime     PM2.5      PM10       NOx       NH3        CO  \
# 0 2017-11-24 17:00:00  0.798129  0.454830  0.196889 -0.584394 -1.076443
# 1 2017-11-24 18:00:00  0.979525  0.742129 -0.009747 -0.377389 -1.076443
# 2 2017-11-24 19:00:00  1.505572  1.192050 -0.004549 -0.010648 -1.076443
# 3 2017-11-24 20:00:00  1.559990  1.219154 -0.324250 -0.082366 -1.076443
# 4 2017-11-24 21:00:00  1.333246  0.845123 -0.311254 -0.009018 -1.076443
#
#         SO2        O3       AQI
# 0 -0.190467  3.506879  95.59999
# 1 -0.078478  3.138017  95.59999
# 2 -0.170954  2.416987  95.59999
# 3 -0.307546  2.942456  95.59999
# 4 -0.422080  2.709930  95.59999

# %%
X = standardscalerdf.drop(columns=['AQI','Datetime'])
y = standardscalerdf['AQI']

# Hitung jumlah sampel untuk data latih (80%) dan data uji (20%)
train_size = int(0.8 * len(df))
test_size = len(df) - train_size

# Bagi data menjadi data latih dan data uji berdasarkan jumlah sampel yang dihitung
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Mengubah data menjadi urutan dengan panjang 48 timestep
X_train = create_sequence(X_train, 24)
X_test  = create_sequence(X_test, 24)

# Menyesuaikan panjang y_train dan y_test
y_train = y_train[-X_train.shape[0]:]
y_test  = y_test[-X_test.shape[0]:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18204, 24, 7)
# X_test shape: (4534, 24, 7)
# y_train shape: (18204,)
# y_test shape: (4534,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, LSTM
from sklearn.metrics import r2_score, mean_absolute_error

# Inisialisasi model Sequential
model_lstm = Sequential()

# Tambahkan lapisan LSTM dengan 50 unit dan input_shape=(1, jumlah_fitur)
model_lstm.add(Conv1D(64, kernel_size=3, input_shape=(X_train.shape[1], X_train.shape[-1])))
model_lstm.add(LSTM(64))

# Tambahkan lapisan Dense dengan 1 neuron (untuk output regresi)
model_lstm.add(Dense(1))

# Kompilasi model dengan mean squared error sebagai loss function dan optimizer adam
model_lstm.compile(optimizer='adam', loss='mean_absolute_error')

# Inisialisasi callback untuk menyimpan R-squared
callback2 = MetricsHistory()

# Latih model menggunakan data latih dengan callback R2History
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, callbacks=[callback2])

# Prediksi menggunakan data uji
y_pred_lstm = model_lstm.predict(X_test)
# Out:
# Epoch 1/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 1 - MAE: 33.031217
# 285/285 - 8s - loss: 84.8560 - 8s/epoch - 30ms/step
# Epoch 2/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 2 - MAE: 21.318972
# 285/285 - 4s - loss: 65.2467 - 4s/epoch - 14ms/step
# Epoch 3/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 3 - MAE: 17.882647
# 285/285 - 4s - loss: 52.9602 - 4s/epoch - 15ms/step
# Epoch 4/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 4 - MAE: 12.380602
# 285/285 - 4s - loss: 42.2134 - 4s/epoch - 15ms/step
# Epoch 5/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 5 - MAE: 11.199385
# 285/285 - 4s - loss: 33.7215 - 4s/epoch - 15ms/step
# Epoch 6/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 6 - MAE: 10.589724
# 285/285 - 4s - loss: 28.1640 - 4s/epoch - 14ms/step
# Epoch 7/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 7 - MAE: 9.303620
# 285/285 - 4s - loss: 25.6178 - 4s/epoch - 14ms/step
# Epoch 8/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 8 - MAE: 9.072999
# 285/285 - 4s - loss: 23.6264 - 4s/epoch - 16ms/step
# Epoch 9/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 9 - MAE: 8.259793
# 285/285 - 4s - loss: 21.5628 - 4s/epoch - 15ms/step
# Epoch 10/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 10 - MAE: 8.329009
# 285/285 - 4s - loss: 19.5644 - 4s/epoch - 15ms/step
# Epoch 11/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 11 - MAE: 7.044843
# 285/285 - 4s - loss: 17.7197 - 4s/epoch - 15ms/step
# Epoch 12/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 12 - MAE: 7.301112
# 285/285 - 4s - loss: 15.9832 - 4s/epoch - 14ms/step
# Epoch 13/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 13 - MAE: 7.003608
# 285/285 - 4s - loss: 14.4753 - 4s/epoch - 14ms/step
# Epoch 14/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 14 - MAE: 6.726377
# 285/285 - 4s - loss: 13.2238 - 4s/epoch - 14ms/step
# Epoch 15/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 15 - MAE: 7.134772
# 285/285 - 4s - loss: 12.1967 - 4s/epoch - 15ms/step
# Epoch 16/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 16 - MAE: 6.073393
# 285/285 - 4s - loss: 11.2448 - 4s/epoch - 14ms/step
# Epoch 17/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 17 - MAE: 6.292243
# 285/285 - 4s - loss: 10.5697 - 4s/epoch - 14ms/step
# Epoch 18/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 18 - MAE: 5.894745
# 285/285 - 4s - loss: 9.8642 - 4s/epoch - 14ms/step
# Epoch 19/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 19 - MAE: 5.903636
# 285/285 - 4s - loss: 9.2600 - 4s/epoch - 15ms/step
# Epoch 20/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 20 - MAE: 5.877517
# 285/285 - 4s - loss: 8.7103 - 4s/epoch - 14ms/step
# Epoch 21/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 21 - MAE: 5.590422
# 285/285 - 4s - loss: 8.2013 - 4s/epoch - 16ms/step
# Epoch 22/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 22 - MAE: 5.624279
# 285/285 - 4s - loss: 7.6907 - 4s/epoch - 15ms/step
# Epoch 23/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 23 - MAE: 5.658658
# 285/285 - 4s - loss: 7.3208 - 4s/epoch - 15ms/step
# Epoch 24/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 24 - MAE: 5.432641
# 285/285 - 4s - loss: 6.9166 - 4s/epoch - 14ms/step
# Epoch 25/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 25 - MAE: 5.293455
# 285/285 - 4s - loss: 6.6997 - 4s/epoch - 14ms/step
# Epoch 26/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 26 - MAE: 5.357688
# 285/285 - 4s - loss: 6.3124 - 4s/epoch - 14ms/step
# Epoch 27/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 27 - MAE: 5.505020
# 285/285 - 4s - loss: 5.9870 - 4s/epoch - 15ms/step
# Epoch 28/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 28 - MAE: 5.548367
# 285/285 - 4s - loss: 5.7684 - 4s/epoch - 15ms/step
# Epoch 29/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 29 - MAE: 5.196039
# 285/285 - 4s - loss: 5.5560 - 4s/epoch - 15ms/step
# Epoch 30/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 30 - MAE: 5.136190
# 285/285 - 4s - loss: 5.2916 - 4s/epoch - 15ms/step
# Epoch 31/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 31 - MAE: 5.590568
# 285/285 - 4s - loss: 5.0507 - 4s/epoch - 14ms/step
# Epoch 32/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 32 - MAE: 5.387558
# 285/285 - 4s - loss: 4.8635 - 4s/epoch - 14ms/step
# Epoch 33/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 33 - MAE: 5.226433
# 285/285 - 4s - loss: 4.7362 - 4s/epoch - 15ms/step
# Epoch 34/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 34 - MAE: 5.295650
# 285/285 - 4s - loss: 4.5964 - 4s/epoch - 15ms/step
# Epoch 35/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 35 - MAE: 5.231554
# 285/285 - 4s - loss: 4.3711 - 4s/epoch - 15ms/step
# Epoch 36/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 36 - MAE: 5.251566
# 285/285 - 4s - loss: 4.2421 - 4s/epoch - 15ms/step
# Epoch 37/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 37 - MAE: 5.221832
# 285/285 - 4s - loss: 4.2080 - 4s/epoch - 15ms/step
# Epoch 38/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 38 - MAE: 5.112023
# 285/285 - 5s - loss: 4.0111 - 5s/epoch - 16ms/step
# Epoch 39/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 39 - MAE: 5.225094
# 285/285 - 4s - loss: 3.9120 - 4s/epoch - 15ms/step
# Epoch 40/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 40 - MAE: 5.216944
# 285/285 - 4s - loss: 3.7952 - 4s/epoch - 15ms/step
# Epoch 41/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 41 - MAE: 5.156859
# 285/285 - 4s - loss: 3.7959 - 4s/epoch - 15ms/step
# Epoch 42/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 42 - MAE: 5.184009
# 285/285 - 4s - loss: 3.6825 - 4s/epoch - 14ms/step
# Epoch 43/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 43 - MAE: 5.110514
# 285/285 - 4s - loss: 3.6507 - 4s/epoch - 15ms/step
# Epoch 44/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 44 - MAE: 5.135036
# 285/285 - 5s - loss: 3.6068 - 5s/epoch - 16ms/step
# Epoch 45/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 45 - MAE: 5.293505
# 285/285 - 4s - loss: 3.4444 - 4s/epoch - 15ms/step
# Epoch 46/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 46 - MAE: 5.122064
# 285/285 - 5s - loss: 3.4749 - 5s/epoch - 16ms/step
# Epoch 47/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 47 - MAE: 5.127486
# 285/285 - 4s - loss: 3.3266 - 4s/epoch - 15ms/step
# Epoch 48/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 48 - MAE: 4.960544
# 285/285 - 4s - loss: 3.3473 - 4s/epoch - 15ms/step
# Epoch 49/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 49 - MAE: 5.073549
# 285/285 - 4s - loss: 3.2720 - 4s/epoch - 15ms/step
# Epoch 50/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 50 - MAE: 5.043634
# 285/285 - 4s - loss: 3.1953 - 4s/epoch - 15ms/step
# 142/142 [==============================] - 1s 5ms/step

# %%
minmaxdf = df
minmaxdf['Datetime'] = pd.to_datetime(minmaxdf['Datetime'])

datetime = minmaxdf[['Datetime']]
aqi = minmaxdf[['AQI']]

minmaxdf = minmaxdf.drop(columns=['Datetime','AQI'])

minmaxdf.head()
# Out:
#    PM2.5    PM10    NOx    NH3   CO    SO2      O3
# 0  60.50   98.00  18.25   8.50  0.1  11.85  126.40
# 1  65.50  111.25  15.07   9.77  0.1  13.17  117.12
# 2  80.00  132.00  15.15  12.02  0.1  12.08   98.98
# 3  81.50  133.25  10.23  11.58  0.1  10.47  112.20
# 4  75.25  116.00  10.43  12.03  0.1   9.12  106.35

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(minmaxdf)

# Konversi scaled_data kembali menjadi DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=minmaxdf.columns)

# Gabungkan scaled_df dengan date_column
result_df = pd.concat([datetime, scaled_df, aqi], axis=1)

minmaxdf = result_df

minmaxdf.head()
# Out:
#              Datetime     PM2.5      PM10       NOx       NH3        CO  \
# 0 2017-11-24 17:00:00  0.195300  0.173757  0.056748  0.042452  0.010081
# 1 2017-11-24 18:00:00  0.211507  0.197492  0.046859  0.048870  0.010081
# 2 2017-11-24 19:00:00  0.258509  0.234662  0.047108  0.060242  0.010081
# 3 2017-11-24 20:00:00  0.263371  0.236901  0.031810  0.058018  0.010081
# 4 2017-11-24 21:00:00  0.243112  0.206001  0.032432  0.060292  0.010081
#
#         SO2        O3       AQI
# 0  0.060625  0.631146  95.59999
# 1  0.067395  0.584588  95.59999
# 2  0.061804  0.493578  95.59999
# 3  0.053547  0.559904  95.59999
# 4  0.046623  0.530554  95.59999

# %%
X = minmaxdf.drop(columns=['AQI','Datetime'])
y = minmaxdf['AQI']

# Hitung jumlah sampel untuk data latih (80%) dan data uji (20%)
train_size = int(0.8 * len(df))
test_size = len(df) - train_size

# Bagi data menjadi data latih dan data uji berdasarkan jumlah sampel yang dihitung
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Mengubah data menjadi urutan dengan panjang 48 timestep
X_train = create_sequence(X_train, 24)
X_test  = create_sequence(X_test, 24)

# Menyesuaikan panjang y_train dan y_test
y_train = y_train[-X_train.shape[0]:]
y_test  = y_test[-X_test.shape[0]:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18204, 24, 7)
# X_test shape: (4534, 24, 7)
# y_train shape: (18204,)
# y_test shape: (4534,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, LSTM
from sklearn.metrics import r2_score, mean_absolute_error

# Inisialisasi model Sequential
model_lstm = Sequential()

# Tambahkan lapisan LSTM dengan 50 unit dan input_shape=(1, jumlah_fitur)
model_lstm.add(Conv1D(64, kernel_size=3, input_shape=(X_train.shape[1], X_train.shape[-1])))
model_lstm.add(LSTM(64))

# Tambahkan lapisan Dense dengan 1 neuron (untuk output regresi)
model_lstm.add(Dense(1))

# Kompilasi model dengan mean squared error sebagai loss function dan optimizer adam
model_lstm.compile(optimizer='adam', loss='mean_absolute_error')

# Inisialisasi callback untuk menyimpan R-squared
callback3 = MetricsHistory()

# Latih model menggunakan data latih dengan callback R2History
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, callbacks=[callback3])

# Prediksi menggunakan data uji
y_pred_lstm = model_lstm.predict(X_test)
# Out:
# Epoch 1/50
# 142/142 [==============================] - 2s 5ms/step
# Epoch 1 - MAE: 34.675151
# 285/285 - 10s - loss: 85.8302 - 10s/epoch - 35ms/step
# Epoch 2/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 2 - MAE: 22.017073
# 285/285 - 5s - loss: 66.8958 - 5s/epoch - 16ms/step
# Epoch 3/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 3 - MAE: 20.308936
# 285/285 - 4s - loss: 54.2499 - 4s/epoch - 15ms/step
# Epoch 4/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 4 - MAE: 24.073602
# 285/285 - 4s - loss: 46.8967 - 4s/epoch - 16ms/step
# Epoch 5/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 5 - MAE: 27.942357
# 285/285 - 5s - loss: 42.2707 - 5s/epoch - 16ms/step
# Epoch 6/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 6 - MAE: 15.509945
# 285/285 - 5s - loss: 37.7541 - 5s/epoch - 16ms/step
# Epoch 7/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 7 - MAE: 13.495472
# 285/285 - 5s - loss: 29.5169 - 5s/epoch - 16ms/step
# Epoch 8/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 8 - MAE: 11.427524
# 285/285 - 5s - loss: 27.0955 - 5s/epoch - 16ms/step
# Epoch 9/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 9 - MAE: 12.463329
# 285/285 - 4s - loss: 25.0396 - 4s/epoch - 16ms/step
# Epoch 10/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 10 - MAE: 13.261242
# 285/285 - 4s - loss: 23.0489 - 4s/epoch - 16ms/step
# Epoch 11/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 11 - MAE: 9.927621
# 285/285 - 4s - loss: 21.2171 - 4s/epoch - 16ms/step
# Epoch 12/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 12 - MAE: 9.274919
# 285/285 - 4s - loss: 19.4558 - 4s/epoch - 15ms/step
# Epoch 13/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 13 - MAE: 10.031620
# 285/285 - 4s - loss: 18.0174 - 4s/epoch - 15ms/step
# Epoch 14/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 14 - MAE: 11.008474
# 285/285 - 4s - loss: 16.9260 - 4s/epoch - 15ms/step
# Epoch 15/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 15 - MAE: 9.529417
# 285/285 - 4s - loss: 15.8608 - 4s/epoch - 15ms/step
# Epoch 16/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 16 - MAE: 9.098350
# 285/285 - 4s - loss: 15.0281 - 4s/epoch - 15ms/step
# Epoch 17/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 17 - MAE: 7.646965
# 285/285 - 4s - loss: 14.3211 - 4s/epoch - 15ms/step
# Epoch 18/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 18 - MAE: 7.996586
# 285/285 - 4s - loss: 13.5777 - 4s/epoch - 15ms/step
# Epoch 19/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 19 - MAE: 8.163996
# 285/285 - 4s - loss: 12.8926 - 4s/epoch - 15ms/step
# Epoch 20/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 20 - MAE: 7.650808
# 285/285 - 4s - loss: 12.3263 - 4s/epoch - 16ms/step
# Epoch 21/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 21 - MAE: 7.913654
# 285/285 - 4s - loss: 11.8209 - 4s/epoch - 15ms/step
# Epoch 22/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 22 - MAE: 7.456938
# 285/285 - 4s - loss: 11.3816 - 4s/epoch - 16ms/step
# Epoch 23/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 23 - MAE: 7.106979
# 285/285 - 5s - loss: 10.8264 - 5s/epoch - 17ms/step
# Epoch 24/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 24 - MAE: 7.189361
# 285/285 - 5s - loss: 10.4528 - 5s/epoch - 17ms/step
# Epoch 25/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 25 - MAE: 7.301809
# 285/285 - 5s - loss: 9.9703 - 5s/epoch - 16ms/step
# Epoch 26/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 26 - MAE: 6.475148
# 285/285 - 5s - loss: 9.5165 - 5s/epoch - 16ms/step
# Epoch 27/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 27 - MAE: 6.924882
# 285/285 - 5s - loss: 9.2167 - 5s/epoch - 17ms/step
# Epoch 28/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 28 - MAE: 6.974728
# 285/285 - 5s - loss: 8.7867 - 5s/epoch - 17ms/step
# Epoch 29/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 29 - MAE: 6.695774
# 285/285 - 4s - loss: 8.4557 - 4s/epoch - 15ms/step
# Epoch 30/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 30 - MAE: 6.559445
# 285/285 - 4s - loss: 8.1683 - 4s/epoch - 15ms/step
# Epoch 31/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 31 - MAE: 6.365147
# 285/285 - 4s - loss: 7.8423 - 4s/epoch - 14ms/step
# Epoch 32/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 32 - MAE: 5.913921
# 285/285 - 4s - loss: 7.7140 - 4s/epoch - 14ms/step
# Epoch 33/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 33 - MAE: 6.000433
# 285/285 - 4s - loss: 7.4467 - 4s/epoch - 14ms/step
# Epoch 34/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 34 - MAE: 6.493902
# 285/285 - 4s - loss: 7.2268 - 4s/epoch - 15ms/step
# Epoch 35/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 35 - MAE: 5.738513
# 285/285 - 4s - loss: 7.0282 - 4s/epoch - 14ms/step
# Epoch 36/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 36 - MAE: 5.738213
# 285/285 - 4s - loss: 6.8518 - 4s/epoch - 15ms/step
# Epoch 37/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 37 - MAE: 5.966862
# 285/285 - 4s - loss: 6.7058 - 4s/epoch - 15ms/step
# Epoch 38/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 38 - MAE: 5.910395
# 285/285 - 5s - loss: 6.5534 - 5s/epoch - 16ms/step
# Epoch 39/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 39 - MAE: 5.628674
# 285/285 - 5s - loss: 6.3735 - 5s/epoch - 16ms/step
# Epoch 40/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 40 - MAE: 5.542045
# 285/285 - 5s - loss: 6.2427 - 5s/epoch - 17ms/step
# Epoch 41/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 41 - MAE: 5.720124
# 285/285 - 5s - loss: 6.1185 - 5s/epoch - 17ms/step
# Epoch 42/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 42 - MAE: 5.490095
# 285/285 - 5s - loss: 6.0795 - 5s/epoch - 18ms/step
# Epoch 43/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 43 - MAE: 5.503705
# 285/285 - 5s - loss: 5.9040 - 5s/epoch - 17ms/step
# Epoch 44/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 44 - MAE: 5.353321
# 285/285 - 5s - loss: 5.8103 - 5s/epoch - 18ms/step
# Epoch 45/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 45 - MAE: 5.291419
# 285/285 - 5s - loss: 5.6838 - 5s/epoch - 19ms/step
# Epoch 46/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 46 - MAE: 5.002573
# 285/285 - 5s - loss: 5.6193 - 5s/epoch - 17ms/step
# Epoch 47/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 47 - MAE: 5.280146
# 285/285 - 5s - loss: 5.6352 - 5s/epoch - 16ms/step
# Epoch 48/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 48 - MAE: 5.862295
# 285/285 - 5s - loss: 5.4556 - 5s/epoch - 17ms/step
# Epoch 49/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 49 - MAE: 5.497489
# 285/285 - 5s - loss: 5.3790 - 5s/epoch - 17ms/step
# Epoch 50/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 50 - MAE: 5.084356
# 285/285 - 5s - loss: 5.2721 - 5s/epoch - 18ms/step
# 142/142 [==============================] - 1s 6ms/step

# %%
robustdf = df
robustdf['Datetime'] = pd.to_datetime(robustdf['Datetime'])

datetime = robustdf[['Datetime']]
aqi = robustdf[['AQI']]

robustdf = robustdf.drop(columns=['Datetime','AQI'])

robustdf.head()
# Out:
#    PM2.5    PM10    NOx    NH3   CO    SO2      O3
# 0  60.50   98.00  18.25   8.50  0.1  11.85  126.40
# 1  65.50  111.25  15.07   9.77  0.1  13.17  117.12
# 2  80.00  132.00  15.15  12.02  0.1  12.08   98.98
# 3  81.50  133.25  10.23  11.58  0.1  10.47  112.20
# 4  75.25  116.00  10.43  12.03  0.1   9.12  106.35

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

scaled_data = scaler.fit_transform(robustdf)

# Konversi scaled_data kembali menjadi DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=robustdf.columns)

# Gabungkan scaled_df dengan date_column
result_df = pd.concat([datetime, scaled_df, aqi], axis=1)

robustdf = result_df

robustdf.head()
# Out:
#              Datetime     PM2.5      PM10       NOx       NH3        CO  \
# 0 2017-11-24 17:00:00  0.847458  0.414605  0.807467 -0.491140 -1.787933
# 1 2017-11-24 18:00:00  1.016949  0.664311  0.436406 -0.317168 -1.787933
# 2 2017-11-24 19:00:00  1.508475  1.055359  0.445741 -0.008949 -1.787933
# 3 2017-11-24 20:00:00  1.559322  1.078916 -0.128355 -0.069223 -1.787933
# 4 2017-11-24 21:00:00  1.347458  0.753828 -0.105017 -0.007579 -1.787933
#
#         SO2        O3       AQI
# 0 -0.216058  3.626932  95.59999
# 1 -0.023358  3.249390  95.59999
# 2 -0.182482  2.511391  95.59999
# 3 -0.417518  3.049227  95.59999
# 4 -0.614599  2.811229  95.59999

# %%
X = robustdf.drop(columns=['AQI','Datetime'])
y = robustdf['AQI']

# Hitung jumlah sampel untuk data latih (80%) dan data uji (20%)
train_size = int(0.8 * len(df))
test_size = len(df) - train_size

# Bagi data menjadi data latih dan data uji berdasarkan jumlah sampel yang dihitung
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Mengubah data menjadi urutan dengan panjang 48 timestep
X_train = create_sequence(X_train, 24)
X_test  = create_sequence(X_test, 24)

# Menyesuaikan panjang y_train dan y_test
y_train = y_train[-X_train.shape[0]:]
y_test  = y_test[-X_test.shape[0]:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18204, 24, 7)
# X_test shape: (4534, 24, 7)
# y_train shape: (18204,)
# y_test shape: (4534,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv1D, LSTM
from sklearn.metrics import r2_score, mean_absolute_error

# Inisialisasi model Sequential
model_lstm = Sequential()

# Tambahkan lapisan LSTM dengan 50 unit dan input_shape=(1, jumlah_fitur)
model_lstm.add(Conv1D(64, kernel_size=3, input_shape=(X_train.shape[1], X_train.shape[-1])))
model_lstm.add(LSTM(64))

# Tambahkan lapisan Dense dengan 1 neuron (untuk output regresi)
model_lstm.add(Dense(1))

# Kompilasi model dengan mean squared error sebagai loss function dan optimizer adam
model_lstm.compile(optimizer='adam', loss='mean_absolute_error')

# Inisialisasi callback untuk menyimpan R-squared
callback4 = MetricsHistory()

# Latih model menggunakan data latih dengan callback R2History
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, callbacks=[callback4])

# Prediksi menggunakan data uji
y_pred_lstm = model_lstm.predict(X_test)
# Out:
# Epoch 1/50
# 142/142 [==============================] - 2s 5ms/step
# Epoch 1 - MAE: 34.592538
# 285/285 - 10s - loss: 86.1014 - 10s/epoch - 35ms/step
# Epoch 2/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 2 - MAE: 21.930801
# 285/285 - 5s - loss: 66.6375 - 5s/epoch - 18ms/step
# Epoch 3/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 3 - MAE: 15.331970
# 285/285 - 5s - loss: 53.3241 - 5s/epoch - 18ms/step
# Epoch 4/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 4 - MAE: 12.776024
# 285/285 - 5s - loss: 42.3134 - 5s/epoch - 17ms/step
# Epoch 5/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 5 - MAE: 10.876207
# 285/285 - 5s - loss: 33.9933 - 5s/epoch - 18ms/step
# Epoch 6/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 6 - MAE: 9.993700
# 285/285 - 5s - loss: 28.1906 - 5s/epoch - 17ms/step
# Epoch 7/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 7 - MAE: 9.247887
# 285/285 - 5s - loss: 25.5511 - 5s/epoch - 17ms/step
# Epoch 8/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 8 - MAE: 8.568179
# 285/285 - 5s - loss: 23.4659 - 5s/epoch - 17ms/step
# Epoch 9/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 9 - MAE: 8.300927
# 285/285 - 5s - loss: 21.6544 - 5s/epoch - 16ms/step
# Epoch 10/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 10 - MAE: 7.812979
# 285/285 - 5s - loss: 19.8600 - 5s/epoch - 17ms/step
# Epoch 11/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 11 - MAE: 7.370582
# 285/285 - 5s - loss: 18.1827 - 5s/epoch - 17ms/step
# Epoch 12/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 12 - MAE: 6.886643
# 285/285 - 5s - loss: 16.5573 - 5s/epoch - 16ms/step
# Epoch 13/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 13 - MAE: 6.719823
# 285/285 - 5s - loss: 14.9882 - 5s/epoch - 17ms/step
# Epoch 14/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 14 - MAE: 6.365061
# 285/285 - 5s - loss: 13.7158 - 5s/epoch - 17ms/step
# Epoch 15/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 15 - MAE: 6.355556
# 285/285 - 5s - loss: 12.7432 - 5s/epoch - 17ms/step
# Epoch 16/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 16 - MAE: 6.357394
# 285/285 - 5s - loss: 11.8051 - 5s/epoch - 18ms/step
# Epoch 17/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 17 - MAE: 5.855196
# 285/285 - 5s - loss: 11.0267 - 5s/epoch - 17ms/step
# Epoch 18/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 18 - MAE: 6.049364
# 285/285 - 5s - loss: 10.3257 - 5s/epoch - 17ms/step
# Epoch 19/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 19 - MAE: 5.360019
# 285/285 - 5s - loss: 9.8334 - 5s/epoch - 17ms/step
# Epoch 20/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 20 - MAE: 5.630020
# 285/285 - 5s - loss: 9.2454 - 5s/epoch - 17ms/step
# Epoch 21/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 21 - MAE: 5.495756
# 285/285 - 4s - loss: 8.7304 - 4s/epoch - 14ms/step
# Epoch 22/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 22 - MAE: 5.466478
# 285/285 - 4s - loss: 8.2786 - 4s/epoch - 14ms/step
# Epoch 23/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 23 - MAE: 5.278219
# 285/285 - 4s - loss: 7.8870 - 4s/epoch - 14ms/step
# Epoch 24/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 24 - MAE: 5.402767
# 285/285 - 4s - loss: 7.5300 - 4s/epoch - 13ms/step
# Epoch 25/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 25 - MAE: 5.265719
# 285/285 - 4s - loss: 7.1317 - 4s/epoch - 14ms/step
# Epoch 26/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 26 - MAE: 5.322742
# 285/285 - 4s - loss: 6.8045 - 4s/epoch - 14ms/step
# Epoch 27/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 27 - MAE: 5.146621
# 285/285 - 4s - loss: 6.4649 - 4s/epoch - 14ms/step
# Epoch 28/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 28 - MAE: 5.582154
# 285/285 - 4s - loss: 6.2803 - 4s/epoch - 14ms/step
# Epoch 29/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 29 - MAE: 5.303193
# 285/285 - 4s - loss: 6.0542 - 4s/epoch - 13ms/step
# Epoch 30/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 30 - MAE: 5.317668
# 285/285 - 4s - loss: 5.8322 - 4s/epoch - 14ms/step
# Epoch 31/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 31 - MAE: 5.344679
# 285/285 - 4s - loss: 5.6746 - 4s/epoch - 14ms/step
# Epoch 32/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 32 - MAE: 5.234584
# 285/285 - 4s - loss: 5.4641 - 4s/epoch - 14ms/step
# Epoch 33/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 33 - MAE: 5.362591
# 285/285 - 4s - loss: 5.2923 - 4s/epoch - 14ms/step
# Epoch 34/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 34 - MAE: 5.309244
# 285/285 - 4s - loss: 5.2404 - 4s/epoch - 14ms/step
# Epoch 35/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 35 - MAE: 5.472118
# 285/285 - 4s - loss: 5.0446 - 4s/epoch - 14ms/step
# Epoch 36/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 36 - MAE: 5.148553
# 285/285 - 4s - loss: 4.9200 - 4s/epoch - 14ms/step
# Epoch 37/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 37 - MAE: 5.342683
# 285/285 - 4s - loss: 4.7082 - 4s/epoch - 14ms/step
# Epoch 38/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 38 - MAE: 5.281999
# 285/285 - 4s - loss: 4.6513 - 4s/epoch - 14ms/step
# Epoch 39/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 39 - MAE: 5.217742
# 285/285 - 4s - loss: 4.4789 - 4s/epoch - 14ms/step
# Epoch 40/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 40 - MAE: 5.343790
# 285/285 - 4s - loss: 4.3763 - 4s/epoch - 14ms/step
# Epoch 41/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 41 - MAE: 5.188385
# 285/285 - 4s - loss: 4.2997 - 4s/epoch - 14ms/step
# Epoch 42/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 42 - MAE: 5.184798
# 285/285 - 4s - loss: 4.1927 - 4s/epoch - 14ms/step
# Epoch 43/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 43 - MAE: 5.075057
# 285/285 - 4s - loss: 4.0822 - 4s/epoch - 14ms/step
# Epoch 44/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 44 - MAE: 5.107569
# 285/285 - 4s - loss: 4.0692 - 4s/epoch - 14ms/step
# Epoch 45/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 45 - MAE: 5.082481
# 285/285 - 4s - loss: 4.0116 - 4s/epoch - 14ms/step
# Epoch 46/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 46 - MAE: 5.137166
# 285/285 - 4s - loss: 3.9311 - 4s/epoch - 14ms/step
# Epoch 47/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 47 - MAE: 5.105664
# 285/285 - 4s - loss: 3.8185 - 4s/epoch - 14ms/step
# Epoch 48/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 48 - MAE: 5.236484
# 285/285 - 4s - loss: 3.7974 - 4s/epoch - 14ms/step
# Epoch 49/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 49 - MAE: 4.998651
# 285/285 - 4s - loss: 3.7623 - 4s/epoch - 14ms/step
# Epoch 50/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 50 - MAE: 5.263551
# 285/285 - 4s - loss: 3.6513 - 4s/epoch - 14ms/step
# 142/142 [==============================] - 1s 5ms/step

# %%
# Plot R-squared per epoch
plt.figure(figsize=(24, 6))

plt.subplot(1, 2, 1)
plt.plot(np.arange(1, 51), callback.mae_scores, marker='o', linestyle='-', color='r', label='Raw')
plt.plot(np.arange(1, 51), callback2.mae_scores, marker='o', linestyle='-', color='g', label='StandardScaler')
plt.plot(np.arange(1, 51), callback3.mae_scores, marker='o', linestyle='-', color='b', label='MinMaxScaler')
plt.plot(np.arange(1, 51), callback4.mae_scores, marker='o', linestyle='-', color='orange', label='RobustScaler')
plt.title('CNN-LSTM Mean Absolute Error (MAE)')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.grid(True)

plt.legend()

plt.show()
