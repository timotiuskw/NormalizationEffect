# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import r2_score, mean_absolute_error
from keras.callbacks import History
from keras.callbacks import Callback
# Out:
# WARNING:tensorflow:From c:\Users\ACER\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv('./Processed_Dataset.csv')
df = df.drop('Unnamed: 0', axis=1)
df = df.drop(columns=['Xylene','Toluene','Benzene','NO','NO2'])
df['Datetime'] = pd.to_datetime(df['Datetime'])

df.head()
# Out:
#              Datetime  PM2.5    PM10    NOx    NH3   CO    SO2      O3  \
# 0 2017-11-24 17:00:00  60.50   98.00  18.25   8.50  0.1  11.85  126.40
# 1 2017-11-24 18:00:00  65.50  111.25  15.07   9.77  0.1  13.17  117.12
# 2 2017-11-24 19:00:00  80.00  132.00  15.15  12.02  0.1  12.08   98.98
# 3 2017-11-24 20:00:00  81.50  133.25  10.23  11.58  0.1  10.47  112.20
# 4 2017-11-24 21:00:00  75.25  116.00  10.43  12.03  0.1   9.12  106.35
#
#         AQI
# 0  95.59999
# 1  95.59999
# 2  95.59999
# 3  95.59999
# 4  95.59999

# %%
def create_sequence(data, timesteps):
    sequences = []
    for i in range(len(data) - timesteps + 1):
        sequences.append(data[i:i + timesteps])
    return np.array(sequences)

# %%
X = df.drop(columns=['AQI','Datetime'])
y = df['AQI']

# Hitung jumlah sampel untuk data latih (80%) dan data uji (20%)
train_size = int(0.8 * len(df))
test_size = len(df) - train_size

# Bagi data menjadi data latih dan data uji berdasarkan jumlah sampel yang dihitung
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Mengubah data menjadi urutan dengan panjang 48 timestep
X_train = create_sequence(X_train, 24)
X_test  = create_sequence(X_test, 24)

# Menyesuaikan panjang y_train dan y_test
y_train = y_train[-X_train.shape[0]:]
y_test  = y_test[-X_test.shape[0]:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18204, 24, 7)
# X_test shape: (4534, 24, 7)
# y_train shape: (18204,)
# y_test shape: (4534,)

# %%
# Callback untuk menyimpan R-squared dan MAE setiap epoch
class MetricsHistory(Callback):
    def on_train_begin(self, logs={}):
        self.r2_scores = []
        self.mae_scores = []

    def on_epoch_end(self, epoch, logs={}):
        X_val_lstm = X_test
        y_pred = self.model.predict(X_val_lstm)
        
        r2 = r2_score(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        
        self.r2_scores.append(r2)
        self.mae_scores.append(mae)
        
        print(f'Epoch {epoch+1} - MAE: {mae:.6f}')

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional
from sklearn.metrics import r2_score, mean_absolute_error

# Inisialisasi model Sequential
model_lstm = Sequential()

# Tambahkan lapisan LSTM dengan 50 unit dan input_shape=(1, jumlah_fitur)
model_lstm.add(Bidirectional(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[-1]), return_sequences=False)))

# Tambahkan lapisan Dense dengan 1 neuron (untuk output regresi)
model_lstm.add(Dense(1))

# Kompilasi model dengan mean squared error sebagai loss function dan optimizer adam
model_lstm.compile(optimizer='adam', loss='mean_absolute_error')

# Inisialisasi callback untuk menyimpan R-squared
callback = MetricsHistory()

# Latih model menggunakan data latih dengan callback R2History
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, callbacks=[callback])

# Prediksi menggunakan data uji
y_pred_lstm = model_lstm.predict(X_test)
# Out:
# WARNING:tensorflow:From c:\Users\ACER\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\ACER\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\ACER\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 142/142 [==============================] - 3s 5ms/step
# Epoch 1 - MAE: 21.082059
# 285/285 - 15s - loss: 76.6952 - 15s/epoch - 53ms/step
# Epoch 2/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 2 - MAE: 16.886525
# 285/285 - 5s - loss: 48.0252 - 5s/epoch - 16ms/step
# Epoch 3/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 3 - MAE: 10.925700
# 285/285 - 5s - loss: 33.6967 - 5s/epoch - 16ms/step
# Epoch 4/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 4 - MAE: 9.473620
# 285/285 - 5s - loss: 27.1284 - 5s/epoch - 18ms/step
# Epoch 5/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 5 - MAE: 9.011746
# 285/285 - 5s - loss: 23.7964 - 5s/epoch - 16ms/step
# Epoch 6/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 6 - MAE: 8.287596
# 285/285 - 5s - loss: 20.9658 - 5s/epoch - 16ms/step
# Epoch 7/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 7 - MAE: 7.806639
# 285/285 - 5s - loss: 19.0005 - 5s/epoch - 18ms/step
# Epoch 8/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 8 - MAE: 7.666559
# 285/285 - 5s - loss: 17.5456 - 5s/epoch - 18ms/step
# Epoch 9/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 9 - MAE: 8.072991
# 285/285 - 5s - loss: 16.2793 - 5s/epoch - 18ms/step
# Epoch 10/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 10 - MAE: 6.710998
# 285/285 - 5s - loss: 15.2349 - 5s/epoch - 17ms/step
# Epoch 11/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 11 - MAE: 7.305175
# 285/285 - 4s - loss: 14.7418 - 4s/epoch - 16ms/step
# Epoch 12/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 12 - MAE: 6.332311
# 285/285 - 4s - loss: 13.6485 - 4s/epoch - 16ms/step
# Epoch 13/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 13 - MAE: 6.537586
# 285/285 - 4s - loss: 12.8680 - 4s/epoch - 16ms/step
# Epoch 14/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 14 - MAE: 6.555790
# 285/285 - 4s - loss: 12.2135 - 4s/epoch - 15ms/step
# Epoch 15/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 15 - MAE: 6.925066
# 285/285 - 4s - loss: 11.6549 - 4s/epoch - 15ms/step
# Epoch 16/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 16 - MAE: 6.894579
# 285/285 - 4s - loss: 11.4085 - 4s/epoch - 15ms/step
# Epoch 17/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 17 - MAE: 6.445926
# 285/285 - 4s - loss: 10.9943 - 4s/epoch - 15ms/step
# Epoch 18/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 18 - MAE: 6.349253
# 285/285 - 4s - loss: 10.5885 - 4s/epoch - 15ms/step
# Epoch 19/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 19 - MAE: 6.352031
# 285/285 - 4s - loss: 10.0600 - 4s/epoch - 15ms/step
# Epoch 20/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 20 - MAE: 6.071451
# 285/285 - 4s - loss: 9.6967 - 4s/epoch - 15ms/step
# Epoch 21/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 21 - MAE: 6.692631
# 285/285 - 4s - loss: 9.5694 - 4s/epoch - 15ms/step
# Epoch 22/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 22 - MAE: 6.178190
# 285/285 - 4s - loss: 9.3884 - 4s/epoch - 15ms/step
# Epoch 23/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 23 - MAE: 6.712721
# 285/285 - 4s - loss: 8.9924 - 4s/epoch - 14ms/step
# Epoch 24/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 24 - MAE: 6.010549
# 285/285 - 4s - loss: 8.5782 - 4s/epoch - 15ms/step
# Epoch 25/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 25 - MAE: 6.364748
# 285/285 - 4s - loss: 8.6219 - 4s/epoch - 15ms/step
# Epoch 26/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 26 - MAE: 5.942672
# 285/285 - 4s - loss: 8.3715 - 4s/epoch - 15ms/step
# Epoch 27/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 27 - MAE: 6.337558
# 285/285 - 4s - loss: 8.2734 - 4s/epoch - 15ms/step
# Epoch 28/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 28 - MAE: 6.030818
# 285/285 - 4s - loss: 7.9674 - 4s/epoch - 15ms/step
# Epoch 29/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 29 - MAE: 6.017078
# 285/285 - 4s - loss: 8.6341 - 4s/epoch - 14ms/step
# Epoch 30/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 30 - MAE: 6.282327
# 285/285 - 4s - loss: 7.8696 - 4s/epoch - 15ms/step
# Epoch 31/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 31 - MAE: 5.886693
# 285/285 - 4s - loss: 7.8105 - 4s/epoch - 15ms/step
# Epoch 32/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 32 - MAE: 6.002807
# 285/285 - 4s - loss: 7.4940 - 4s/epoch - 14ms/step
# Epoch 33/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 33 - MAE: 6.006124
# 285/285 - 4s - loss: 7.4918 - 4s/epoch - 15ms/step
# Epoch 34/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 34 - MAE: 5.925915
# 285/285 - 4s - loss: 7.1955 - 4s/epoch - 14ms/step
# Epoch 35/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 35 - MAE: 6.315753
# 285/285 - 4s - loss: 7.2079 - 4s/epoch - 14ms/step
# Epoch 36/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 36 - MAE: 5.829361
# 285/285 - 4s - loss: 7.0459 - 4s/epoch - 15ms/step
# Epoch 37/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 37 - MAE: 6.430742
# 285/285 - 4s - loss: 6.9873 - 4s/epoch - 15ms/step
# Epoch 38/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 38 - MAE: 6.612956
# 285/285 - 4s - loss: 6.9906 - 4s/epoch - 15ms/step
# Epoch 39/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 39 - MAE: 6.489616
# 285/285 - 4s - loss: 6.6546 - 4s/epoch - 15ms/step
# Epoch 40/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 40 - MAE: 5.942150
# 285/285 - 4s - loss: 6.7492 - 4s/epoch - 15ms/step
# Epoch 41/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 41 - MAE: 6.725114
# 285/285 - 4s - loss: 6.6755 - 4s/epoch - 15ms/step
# Epoch 42/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 42 - MAE: 6.241227
# 285/285 - 5s - loss: 6.5889 - 5s/epoch - 16ms/step
# Epoch 43/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 43 - MAE: 6.151242
# 285/285 - 4s - loss: 6.6014 - 4s/epoch - 15ms/step
# Epoch 44/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 44 - MAE: 6.060705
# 285/285 - 5s - loss: 6.4688 - 5s/epoch - 17ms/step
# Epoch 45/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 45 - MAE: 6.142699
# 285/285 - 4s - loss: 6.4252 - 4s/epoch - 16ms/step
# Epoch 46/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 46 - MAE: 6.253529
# 285/285 - 5s - loss: 6.2589 - 5s/epoch - 16ms/step
# Epoch 47/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 47 - MAE: 6.344581
# 285/285 - 5s - loss: 6.2341 - 5s/epoch - 17ms/step
# Epoch 48/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 48 - MAE: 5.953130
# 285/285 - 4s - loss: 6.3861 - 4s/epoch - 16ms/step
# Epoch 49/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 49 - MAE: 5.831987
# 285/285 - 5s - loss: 6.2045 - 5s/epoch - 16ms/step
# Epoch 50/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 50 - MAE: 5.952869
# 285/285 - 4s - loss: 6.0664 - 4s/epoch - 14ms/step
# 142/142 [==============================] - 1s 5ms/step

# %%
standardscalerdf = df
standardscalerdf['Datetime'] = pd.to_datetime(standardscalerdf['Datetime'])

datetime = standardscalerdf[['Datetime']]
aqi = standardscalerdf[['AQI']]

standardscalerdf = standardscalerdf.drop(columns=['Datetime','AQI'])

standardscalerdf.head()
# Out:
#    PM2.5    PM10    NOx    NH3   CO    SO2      O3
# 0  60.50   98.00  18.25   8.50  0.1  11.85  126.40
# 1  65.50  111.25  15.07   9.77  0.1  13.17  117.12
# 2  80.00  132.00  15.15  12.02  0.1  12.08   98.98
# 3  81.50  133.25  10.23  11.58  0.1  10.47  112.20
# 4  75.25  116.00  10.43  12.03  0.1   9.12  106.35

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_data = scaler.fit_transform(standardscalerdf)

# Konversi scaled_data kembali menjadi DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=standardscalerdf.columns)

# Gabungkan scaled_df dengan date_column
result_df = pd.concat([datetime, scaled_df, aqi], axis=1)

standardscalerdf = result_df

standardscalerdf.head()
# Out:
#              Datetime     PM2.5      PM10       NOx       NH3        CO  \
# 0 2017-11-24 17:00:00  0.798129  0.454830  0.196889 -0.584394 -1.076443
# 1 2017-11-24 18:00:00  0.979525  0.742129 -0.009747 -0.377389 -1.076443
# 2 2017-11-24 19:00:00  1.505572  1.192050 -0.004549 -0.010648 -1.076443
# 3 2017-11-24 20:00:00  1.559990  1.219154 -0.324250 -0.082366 -1.076443
# 4 2017-11-24 21:00:00  1.333246  0.845123 -0.311254 -0.009018 -1.076443
#
#         SO2        O3       AQI
# 0 -0.190467  3.506879  95.59999
# 1 -0.078478  3.138017  95.59999
# 2 -0.170954  2.416987  95.59999
# 3 -0.307546  2.942456  95.59999
# 4 -0.422080  2.709930  95.59999

# %%
X = standardscalerdf.drop(columns=['AQI','Datetime'])
y = standardscalerdf['AQI']

# Hitung jumlah sampel untuk data latih (80%) dan data uji (20%)
train_size = int(0.8 * len(df))
test_size = len(df) - train_size

# Bagi data menjadi data latih dan data uji berdasarkan jumlah sampel yang dihitung
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Mengubah data menjadi urutan dengan panjang 48 timestep
X_train = create_sequence(X_train, 24)
X_test  = create_sequence(X_test, 24)

# Menyesuaikan panjang y_train dan y_test
y_train = y_train[-X_train.shape[0]:]
y_test  = y_test[-X_test.shape[0]:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18204, 24, 7)
# X_test shape: (4534, 24, 7)
# y_train shape: (18204,)
# y_test shape: (4534,)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import r2_score, mean_absolute_error

# Inisialisasi model Sequential
model_lstm = Sequential()

# Tambahkan lapisan LSTM dengan 50 unit dan input_shape=(1, jumlah_fitur)
model_lstm.add(Bidirectional(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[-1]), return_sequences=False)))

# Tambahkan lapisan Dense dengan 1 neuron (untuk output regresi)
model_lstm.add(Dense(1))

# Kompilasi model dengan mean squared error sebagai loss function dan optimizer adam
model_lstm.compile(optimizer='adam', loss='mean_absolute_error')

# Inisialisasi callback untuk menyimpan R-squared
callback2 = MetricsHistory()

# Latih model menggunakan data latih dengan callback R2History
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, callbacks=[callback2])

# Prediksi menggunakan data uji
y_pred_lstm = model_lstm.predict(X_test)
# Out:
# Epoch 1/50
# 142/142 [==============================] - 2s 6ms/step
# Epoch 1 - MAE: 20.279706
# 285/285 - 15s - loss: 72.7792 - 15s/epoch - 52ms/step
# Epoch 2/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 2 - MAE: 26.861202
# 285/285 - 4s - loss: 47.2774 - 4s/epoch - 15ms/step
# Epoch 3/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 3 - MAE: 11.442304
# 285/285 - 5s - loss: 37.6768 - 5s/epoch - 16ms/step
# Epoch 4/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 4 - MAE: 10.491855
# 285/285 - 4s - loss: 26.5190 - 4s/epoch - 15ms/step
# Epoch 5/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 5 - MAE: 9.799466
# 285/285 - 4s - loss: 21.8755 - 4s/epoch - 15ms/step
# Epoch 6/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 6 - MAE: 7.703985
# 285/285 - 5s - loss: 18.4531 - 5s/epoch - 16ms/step
# Epoch 7/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 7 - MAE: 7.052225
# 285/285 - 4s - loss: 15.7080 - 4s/epoch - 15ms/step
# Epoch 8/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 8 - MAE: 6.605774
# 285/285 - 4s - loss: 13.4830 - 4s/epoch - 15ms/step
# Epoch 9/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 9 - MAE: 6.062217
# 285/285 - 4s - loss: 11.8041 - 4s/epoch - 16ms/step
# Epoch 10/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 10 - MAE: 6.382412
# 285/285 - 4s - loss: 10.4886 - 4s/epoch - 15ms/step
# Epoch 11/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 11 - MAE: 5.669587
# 285/285 - 5s - loss: 9.5363 - 5s/epoch - 18ms/step
# Epoch 12/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 12 - MAE: 5.544728
# 285/285 - 5s - loss: 8.7140 - 5s/epoch - 16ms/step
# Epoch 13/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 13 - MAE: 5.574187
# 285/285 - 5s - loss: 7.9662 - 5s/epoch - 17ms/step
# Epoch 14/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 14 - MAE: 5.183336
# 285/285 - 5s - loss: 7.4598 - 5s/epoch - 19ms/step
# Epoch 15/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 15 - MAE: 5.261567
# 285/285 - 5s - loss: 7.0185 - 5s/epoch - 19ms/step
# Epoch 16/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 16 - MAE: 5.365361
# 285/285 - 5s - loss: 6.4591 - 5s/epoch - 17ms/step
# Epoch 17/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 17 - MAE: 5.387620
# 285/285 - 5s - loss: 6.0953 - 5s/epoch - 17ms/step
# Epoch 18/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 18 - MAE: 5.290354
# 285/285 - 5s - loss: 5.7107 - 5s/epoch - 17ms/step
# Epoch 19/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 19 - MAE: 5.262244
# 285/285 - 5s - loss: 5.4246 - 5s/epoch - 17ms/step
# Epoch 20/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 20 - MAE: 5.261577
# 285/285 - 5s - loss: 5.1524 - 5s/epoch - 17ms/step
# Epoch 21/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 21 - MAE: 5.033318
# 285/285 - 5s - loss: 5.0359 - 5s/epoch - 17ms/step
# Epoch 22/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 22 - MAE: 5.120052
# 285/285 - 5s - loss: 4.8224 - 5s/epoch - 18ms/step
# Epoch 23/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 23 - MAE: 5.039739
# 285/285 - 5s - loss: 4.4688 - 5s/epoch - 17ms/step
# Epoch 24/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 24 - MAE: 4.911779
# 285/285 - 5s - loss: 4.3417 - 5s/epoch - 17ms/step
# Epoch 25/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 25 - MAE: 5.057810
# 285/285 - 5s - loss: 4.2515 - 5s/epoch - 17ms/step
# Epoch 26/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 26 - MAE: 4.906845
# 285/285 - 5s - loss: 4.1544 - 5s/epoch - 17ms/step
# Epoch 27/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 27 - MAE: 4.958513
# 285/285 - 5s - loss: 3.9748 - 5s/epoch - 17ms/step
# Epoch 28/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 28 - MAE: 4.904195
# 285/285 - 5s - loss: 3.8492 - 5s/epoch - 17ms/step
# Epoch 29/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 29 - MAE: 4.928539
# 285/285 - 5s - loss: 3.8015 - 5s/epoch - 17ms/step
# Epoch 30/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 30 - MAE: 4.984356
# 285/285 - 5s - loss: 3.6530 - 5s/epoch - 17ms/step
# Epoch 31/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 31 - MAE: 5.056746
# 285/285 - 5s - loss: 3.5365 - 5s/epoch - 17ms/step
# Epoch 32/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 32 - MAE: 4.991199
# 285/285 - 5s - loss: 3.5062 - 5s/epoch - 17ms/step
# Epoch 33/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 33 - MAE: 5.079867
# 285/285 - 5s - loss: 3.4931 - 5s/epoch - 18ms/step
# Epoch 34/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 34 - MAE: 4.780688
# 285/285 - 5s - loss: 3.4085 - 5s/epoch - 17ms/step
# Epoch 35/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 35 - MAE: 4.884867
# 285/285 - 5s - loss: 3.2249 - 5s/epoch - 19ms/step
# Epoch 36/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 36 - MAE: 4.791398
# 285/285 - 5s - loss: 3.1434 - 5s/epoch - 18ms/step
# Epoch 37/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 37 - MAE: 5.053368
# 285/285 - 5s - loss: 3.0430 - 5s/epoch - 19ms/step
# Epoch 38/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 38 - MAE: 5.167612
# 285/285 - 5s - loss: 3.0146 - 5s/epoch - 19ms/step
# Epoch 39/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 39 - MAE: 5.013414
# 285/285 - 5s - loss: 2.9719 - 5s/epoch - 18ms/step
# Epoch 40/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 40 - MAE: 4.833407
# 285/285 - 5s - loss: 2.9946 - 5s/epoch - 17ms/step
# Epoch 41/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 41 - MAE: 5.057115
# 285/285 - 5s - loss: 2.9698 - 5s/epoch - 17ms/step
# Epoch 42/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 42 - MAE: 5.183591
# 285/285 - 5s - loss: 2.8779 - 5s/epoch - 18ms/step
# Epoch 43/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 43 - MAE: 5.032176
# 285/285 - 5s - loss: 2.8227 - 5s/epoch - 19ms/step
# Epoch 44/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 44 - MAE: 4.824346
# 285/285 - 5s - loss: 2.8710 - 5s/epoch - 18ms/step
# Epoch 45/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 45 - MAE: 5.016654
# 285/285 - 5s - loss: 2.7963 - 5s/epoch - 17ms/step
# Epoch 46/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 46 - MAE: 5.301752
# 285/285 - 5s - loss: 2.8092 - 5s/epoch - 19ms/step
# Epoch 47/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 47 - MAE: 5.074951
# 285/285 - 5s - loss: 2.6748 - 5s/epoch - 18ms/step
# Epoch 48/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 48 - MAE: 4.785567
# 285/285 - 5s - loss: 2.6086 - 5s/epoch - 17ms/step
# Epoch 49/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 49 - MAE: 5.141537
# 285/285 - 5s - loss: 2.5707 - 5s/epoch - 17ms/step
# Epoch 50/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 50 - MAE: 5.256455
# 285/285 - 5s - loss: 2.5396 - 5s/epoch - 16ms/step
# 142/142 [==============================] - 1s 7ms/step

# %%
minmaxdf = df
minmaxdf['Datetime'] = pd.to_datetime(minmaxdf['Datetime'])

datetime = minmaxdf[['Datetime']]
aqi = minmaxdf[['AQI']]

minmaxdf = minmaxdf.drop(columns=['Datetime','AQI'])

minmaxdf.head()
# Out:
#    PM2.5    PM10    NOx    NH3   CO    SO2      O3
# 0  60.50   98.00  18.25   8.50  0.1  11.85  126.40
# 1  65.50  111.25  15.07   9.77  0.1  13.17  117.12
# 2  80.00  132.00  15.15  12.02  0.1  12.08   98.98
# 3  81.50  133.25  10.23  11.58  0.1  10.47  112.20
# 4  75.25  116.00  10.43  12.03  0.1   9.12  106.35

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(minmaxdf)

# Konversi scaled_data kembali menjadi DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=minmaxdf.columns)

# Gabungkan scaled_df dengan date_column
result_df = pd.concat([datetime, scaled_df, aqi], axis=1)

minmaxdf = result_df

minmaxdf.head()
# Out:
#              Datetime     PM2.5      PM10       NOx       NH3        CO  \
# 0 2017-11-24 17:00:00  0.195300  0.173757  0.056748  0.042452  0.010081
# 1 2017-11-24 18:00:00  0.211507  0.197492  0.046859  0.048870  0.010081
# 2 2017-11-24 19:00:00  0.258509  0.234662  0.047108  0.060242  0.010081
# 3 2017-11-24 20:00:00  0.263371  0.236901  0.031810  0.058018  0.010081
# 4 2017-11-24 21:00:00  0.243112  0.206001  0.032432  0.060292  0.010081
#
#         SO2        O3       AQI
# 0  0.060625  0.631146  95.59999
# 1  0.067395  0.584588  95.59999
# 2  0.061804  0.493578  95.59999
# 3  0.053547  0.559904  95.59999
# 4  0.046623  0.530554  95.59999

# %%
X = minmaxdf.drop(columns=['AQI','Datetime'])
y = minmaxdf['AQI']

# Hitung jumlah sampel untuk data latih (80%) dan data uji (20%)
train_size = int(0.8 * len(df))
test_size = len(df) - train_size

# Bagi data menjadi data latih dan data uji berdasarkan jumlah sampel yang dihitung
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Mengubah data menjadi urutan dengan panjang 48 timestep
X_train = create_sequence(X_train, 24)
X_test  = create_sequence(X_test, 24)

# Menyesuaikan panjang y_train dan y_test
y_train = y_train[-X_train.shape[0]:]
y_test  = y_test[-X_test.shape[0]:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18204, 24, 7)
# X_test shape: (4534, 24, 7)
# y_train shape: (18204,)
# y_test shape: (4534,)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import r2_score, mean_absolute_error

# Inisialisasi model Sequential
model_lstm = Sequential()

# Tambahkan lapisan LSTM dengan 50 unit dan input_shape=(1, jumlah_fitur)
model_lstm.add(Bidirectional(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[-1]), return_sequences=False)))

# Tambahkan lapisan Dense dengan 1 neuron (untuk output regresi)
model_lstm.add(Dense(1))

# Kompilasi model dengan mean squared error sebagai loss function dan optimizer adam
model_lstm.compile(optimizer='adam', loss='mean_absolute_error')

# Inisialisasi callback untuk menyimpan R-squared
callback3 = MetricsHistory()

# Latih model menggunakan data latih dengan callback R2History
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, callbacks=[callback3])

# Prediksi menggunakan data uji
y_pred_lstm = model_lstm.predict(X_test)
# Out:
# Epoch 1/50
# 142/142 [==============================] - 3s 6ms/step
# Epoch 1 - MAE: 20.666473
# 285/285 - 18s - loss: 74.1419 - 18s/epoch - 62ms/step
# Epoch 2/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 2 - MAE: 25.925727
# 285/285 - 5s - loss: 48.2699 - 5s/epoch - 18ms/step
# Epoch 3/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 3 - MAE: 35.480623
# 285/285 - 5s - loss: 40.5824 - 5s/epoch - 18ms/step
# Epoch 4/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 4 - MAE: 39.094288
# 285/285 - 5s - loss: 38.5064 - 5s/epoch - 18ms/step
# Epoch 5/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 5 - MAE: 35.152419
# 285/285 - 5s - loss: 38.2248 - 5s/epoch - 17ms/step
# Epoch 6/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 6 - MAE: 14.336479
# 285/285 - 5s - loss: 29.4026 - 5s/epoch - 16ms/step
# Epoch 7/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 7 - MAE: 12.059465
# 285/285 - 5s - loss: 25.0414 - 5s/epoch - 18ms/step
# Epoch 8/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 8 - MAE: 11.481798
# 285/285 - 5s - loss: 21.9268 - 5s/epoch - 16ms/step
# Epoch 9/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 9 - MAE: 9.914906
# 285/285 - 5s - loss: 19.6028 - 5s/epoch - 17ms/step
# Epoch 10/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 10 - MAE: 10.127552
# 285/285 - 5s - loss: 17.8781 - 5s/epoch - 18ms/step
# Epoch 11/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 11 - MAE: 13.155080
# 285/285 - 5s - loss: 16.4602 - 5s/epoch - 17ms/step
# Epoch 12/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 12 - MAE: 8.473025
# 285/285 - 5s - loss: 15.2801 - 5s/epoch - 17ms/step
# Epoch 13/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 13 - MAE: 10.461000
# 285/285 - 5s - loss: 14.4088 - 5s/epoch - 17ms/step
# Epoch 14/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 14 - MAE: 9.456611
# 285/285 - 5s - loss: 13.2729 - 5s/epoch - 17ms/step
# Epoch 15/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 15 - MAE: 8.846636
# 285/285 - 5s - loss: 12.4736 - 5s/epoch - 17ms/step
# Epoch 16/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 16 - MAE: 8.429619
# 285/285 - 5s - loss: 11.6781 - 5s/epoch - 17ms/step
# Epoch 17/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 17 - MAE: 8.699863
# 285/285 - 5s - loss: 11.1813 - 5s/epoch - 17ms/step
# Epoch 18/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 18 - MAE: 8.970688
# 285/285 - 5s - loss: 10.6203 - 5s/epoch - 16ms/step
# Epoch 19/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 19 - MAE: 8.464599
# 285/285 - 5s - loss: 10.1915 - 5s/epoch - 17ms/step
# Epoch 20/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 20 - MAE: 7.458897
# 285/285 - 5s - loss: 9.8490 - 5s/epoch - 16ms/step
# Epoch 21/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 21 - MAE: 7.933315
# 285/285 - 5s - loss: 9.4848 - 5s/epoch - 17ms/step
# Epoch 22/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 22 - MAE: 8.553383
# 285/285 - 5s - loss: 9.0208 - 5s/epoch - 17ms/step
# Epoch 23/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 23 - MAE: 8.470926
# 285/285 - 5s - loss: 8.8011 - 5s/epoch - 16ms/step
# Epoch 24/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 24 - MAE: 7.537940
# 285/285 - 5s - loss: 8.2564 - 5s/epoch - 18ms/step
# Epoch 25/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 25 - MAE: 8.658701
# 285/285 - 6s - loss: 8.1610 - 6s/epoch - 20ms/step
# Epoch 26/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 26 - MAE: 7.105099
# 285/285 - 5s - loss: 8.0974 - 5s/epoch - 19ms/step
# Epoch 27/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 27 - MAE: 6.757842
# 285/285 - 5s - loss: 7.7592 - 5s/epoch - 17ms/step
# Epoch 28/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 28 - MAE: 8.021281
# 285/285 - 5s - loss: 7.5952 - 5s/epoch - 16ms/step
# Epoch 29/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 29 - MAE: 6.966761
# 285/285 - 5s - loss: 7.5025 - 5s/epoch - 17ms/step
# Epoch 30/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 30 - MAE: 6.808760
# 285/285 - 5s - loss: 7.2196 - 5s/epoch - 17ms/step
# Epoch 31/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 31 - MAE: 6.393991
# 285/285 - 5s - loss: 7.1750 - 5s/epoch - 17ms/step
# Epoch 32/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 32 - MAE: 6.299403
# 285/285 - 5s - loss: 7.0913 - 5s/epoch - 17ms/step
# Epoch 33/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 33 - MAE: 6.135453
# 285/285 - 5s - loss: 7.0550 - 5s/epoch - 17ms/step
# Epoch 34/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 34 - MAE: 6.414733
# 285/285 - 5s - loss: 6.7841 - 5s/epoch - 19ms/step
# Epoch 35/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 35 - MAE: 6.752367
# 285/285 - 5s - loss: 6.8272 - 5s/epoch - 19ms/step
# Epoch 36/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 36 - MAE: 5.988606
# 285/285 - 5s - loss: 6.6263 - 5s/epoch - 16ms/step
# Epoch 37/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 37 - MAE: 6.828053
# 285/285 - 4s - loss: 6.6693 - 4s/epoch - 16ms/step
# Epoch 38/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 38 - MAE: 5.719549
# 285/285 - 5s - loss: 6.4140 - 5s/epoch - 16ms/step
# Epoch 39/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 39 - MAE: 5.622161
# 285/285 - 5s - loss: 6.3393 - 5s/epoch - 16ms/step
# Epoch 40/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 40 - MAE: 5.521668
# 285/285 - 5s - loss: 6.2790 - 5s/epoch - 18ms/step
# Epoch 41/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 41 - MAE: 5.232733
# 285/285 - 5s - loss: 6.2831 - 5s/epoch - 16ms/step
# Epoch 42/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 42 - MAE: 5.706669
# 285/285 - 4s - loss: 6.1764 - 4s/epoch - 15ms/step
# Epoch 43/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 43 - MAE: 5.407441
# 285/285 - 4s - loss: 6.0520 - 4s/epoch - 15ms/step
# Epoch 44/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 44 - MAE: 6.535824
# 285/285 - 5s - loss: 6.0561 - 5s/epoch - 16ms/step
# Epoch 45/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 45 - MAE: 5.347463
# 285/285 - 5s - loss: 5.8398 - 5s/epoch - 16ms/step
# Epoch 46/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 46 - MAE: 5.634036
# 285/285 - 5s - loss: 6.0772 - 5s/epoch - 16ms/step
# Epoch 47/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 47 - MAE: 5.970390
# 285/285 - 5s - loss: 5.8297 - 5s/epoch - 17ms/step
# Epoch 48/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 48 - MAE: 5.795662
# 285/285 - 4s - loss: 5.8041 - 4s/epoch - 15ms/step
# Epoch 49/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 49 - MAE: 5.760920
# 285/285 - 4s - loss: 5.7456 - 4s/epoch - 15ms/step
# Epoch 50/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 50 - MAE: 5.836462
# 285/285 - 4s - loss: 5.8605 - 4s/epoch - 15ms/step
# 142/142 [==============================] - 1s 6ms/step

# %%
robustdf = df
robustdf['Datetime'] = pd.to_datetime(robustdf['Datetime'])

datetime = robustdf[['Datetime']]
aqi = robustdf[['AQI']]

robustdf = robustdf.drop(columns=['Datetime','AQI'])

robustdf.head()
# Out:
#    PM2.5    PM10    NOx    NH3   CO    SO2      O3
# 0  60.50   98.00  18.25   8.50  0.1  11.85  126.40
# 1  65.50  111.25  15.07   9.77  0.1  13.17  117.12
# 2  80.00  132.00  15.15  12.02  0.1  12.08   98.98
# 3  81.50  133.25  10.23  11.58  0.1  10.47  112.20
# 4  75.25  116.00  10.43  12.03  0.1   9.12  106.35

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

scaled_data = scaler.fit_transform(robustdf)

# Konversi scaled_data kembali menjadi DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=robustdf.columns)

# Gabungkan scaled_df dengan date_column
result_df = pd.concat([datetime, scaled_df, aqi], axis=1)

robustdf = result_df

robustdf.head()
# Out:
#              Datetime     PM2.5      PM10       NOx       NH3        CO  \
# 0 2017-11-24 17:00:00  0.847458  0.414605  0.807467 -0.491140 -1.787933
# 1 2017-11-24 18:00:00  1.016949  0.664311  0.436406 -0.317168 -1.787933
# 2 2017-11-24 19:00:00  1.508475  1.055359  0.445741 -0.008949 -1.787933
# 3 2017-11-24 20:00:00  1.559322  1.078916 -0.128355 -0.069223 -1.787933
# 4 2017-11-24 21:00:00  1.347458  0.753828 -0.105017 -0.007579 -1.787933
#
#         SO2        O3       AQI
# 0 -0.216058  3.626932  95.59999
# 1 -0.023358  3.249390  95.59999
# 2 -0.182482  2.511391  95.59999
# 3 -0.417518  3.049227  95.59999
# 4 -0.614599  2.811229  95.59999

# %%
X = robustdf.drop(columns=['AQI','Datetime'])
y = robustdf['AQI']

# Hitung jumlah sampel untuk data latih (80%) dan data uji (20%)
train_size = int(0.8 * len(df))
test_size = len(df) - train_size

# Bagi data menjadi data latih dan data uji berdasarkan jumlah sampel yang dihitung
X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]

# %%
# Mengubah data menjadi urutan dengan panjang 48 timestep
X_train = create_sequence(X_train, 24)
X_test  = create_sequence(X_test, 24)

# Menyesuaikan panjang y_train dan y_test
y_train = y_train[-X_train.shape[0]:]
y_test  = y_test[-X_test.shape[0]:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18204, 24, 7)
# X_test shape: (4534, 24, 7)
# y_train shape: (18204,)
# y_test shape: (4534,)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import r2_score, mean_absolute_error

# Inisialisasi model Sequential
model_lstm = Sequential()

# Tambahkan lapisan LSTM dengan 50 unit dan input_shape=(1, jumlah_fitur)
model_lstm.add(Bidirectional(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[-1]), return_sequences=False)))

# Tambahkan lapisan Dense dengan 1 neuron (untuk output regresi)
model_lstm.add(Dense(1))

# Kompilasi model dengan mean squared error sebagai loss function dan optimizer adam
model_lstm.compile(optimizer='adam', loss='mean_absolute_error')

# Inisialisasi callback untuk menyimpan R-squared
callback4 = MetricsHistory()

# Latih model menggunakan data latih dengan callback R2History
history = model_lstm.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2, callbacks=[callback4])

# Prediksi menggunakan data uji
y_pred_lstm = model_lstm.predict(X_test)
# Out:
# Epoch 1/50
# 142/142 [==============================] - 3s 5ms/step
# Epoch 1 - MAE: 20.595870
# 285/285 - 17s - loss: 74.5040 - 17s/epoch - 59ms/step
# Epoch 2/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 2 - MAE: 26.227925
# 285/285 - 5s - loss: 48.0356 - 5s/epoch - 16ms/step
# Epoch 3/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 3 - MAE: 12.959157
# 285/285 - 5s - loss: 38.0135 - 5s/epoch - 16ms/step
# Epoch 4/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 4 - MAE: 11.324904
# 285/285 - 4s - loss: 27.1044 - 4s/epoch - 16ms/step
# Epoch 5/50
# 142/142 [==============================] - 1s 9ms/step
# Epoch 5 - MAE: 9.267547
# 285/285 - 5s - loss: 22.6804 - 5s/epoch - 18ms/step
# Epoch 6/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 6 - MAE: 7.661936
# 285/285 - 5s - loss: 18.9717 - 5s/epoch - 18ms/step
# Epoch 7/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 7 - MAE: 6.896949
# 285/285 - 5s - loss: 16.0013 - 5s/epoch - 17ms/step
# Epoch 8/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 8 - MAE: 6.325138
# 285/285 - 5s - loss: 13.7487 - 5s/epoch - 16ms/step
# Epoch 9/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 9 - MAE: 6.143622
# 285/285 - 4s - loss: 12.0371 - 4s/epoch - 15ms/step
# Epoch 10/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 10 - MAE: 5.950116
# 285/285 - 4s - loss: 10.8711 - 4s/epoch - 16ms/step
# Epoch 11/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 11 - MAE: 5.576573
# 285/285 - 5s - loss: 9.7740 - 5s/epoch - 17ms/step
# Epoch 12/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 12 - MAE: 5.452094
# 285/285 - 5s - loss: 8.9352 - 5s/epoch - 16ms/step
# Epoch 13/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 13 - MAE: 5.416941
# 285/285 - 5s - loss: 8.2866 - 5s/epoch - 17ms/step
# Epoch 14/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 14 - MAE: 5.467915
# 285/285 - 5s - loss: 7.6623 - 5s/epoch - 18ms/step
# Epoch 15/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 15 - MAE: 5.607506
# 285/285 - 5s - loss: 7.0713 - 5s/epoch - 18ms/step
# Epoch 16/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 16 - MAE: 5.306675
# 285/285 - 5s - loss: 6.5970 - 5s/epoch - 17ms/step
# Epoch 17/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 17 - MAE: 5.240244
# 285/285 - 5s - loss: 6.2209 - 5s/epoch - 18ms/step
# Epoch 18/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 18 - MAE: 5.136567
# 285/285 - 5s - loss: 5.8514 - 5s/epoch - 19ms/step
# Epoch 19/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 19 - MAE: 5.174534
# 285/285 - 5s - loss: 5.5581 - 5s/epoch - 19ms/step
# Epoch 20/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 20 - MAE: 5.176624
# 285/285 - 5s - loss: 5.2384 - 5s/epoch - 18ms/step
# Epoch 21/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 21 - MAE: 5.240177
# 285/285 - 5s - loss: 4.9925 - 5s/epoch - 18ms/step
# Epoch 22/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 22 - MAE: 5.478153
# 285/285 - 5s - loss: 4.7998 - 5s/epoch - 17ms/step
# Epoch 23/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 23 - MAE: 5.199274
# 285/285 - 5s - loss: 4.5577 - 5s/epoch - 18ms/step
# Epoch 24/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 24 - MAE: 5.052038
# 285/285 - 5s - loss: 4.3483 - 5s/epoch - 16ms/step
# Epoch 25/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 25 - MAE: 5.105770
# 285/285 - 5s - loss: 4.1825 - 5s/epoch - 17ms/step
# Epoch 26/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 26 - MAE: 5.325155
# 285/285 - 5s - loss: 4.1003 - 5s/epoch - 17ms/step
# Epoch 27/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 27 - MAE: 5.221208
# 285/285 - 5s - loss: 3.9010 - 5s/epoch - 17ms/step
# Epoch 28/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 28 - MAE: 5.270337
# 285/285 - 5s - loss: 3.8277 - 5s/epoch - 17ms/step
# Epoch 29/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 29 - MAE: 5.224344
# 285/285 - 5s - loss: 3.6811 - 5s/epoch - 17ms/step
# Epoch 30/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 30 - MAE: 5.319070
# 285/285 - 5s - loss: 3.6052 - 5s/epoch - 18ms/step
# Epoch 31/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 31 - MAE: 5.511441
# 285/285 - 6s - loss: 3.5089 - 6s/epoch - 19ms/step
# Epoch 32/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 32 - MAE: 5.400035
# 285/285 - 5s - loss: 3.4113 - 5s/epoch - 19ms/step
# Epoch 33/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 33 - MAE: 5.347755
# 285/285 - 5s - loss: 3.2843 - 5s/epoch - 19ms/step
# Epoch 34/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 34 - MAE: 5.237027
# 285/285 - 5s - loss: 3.3217 - 5s/epoch - 17ms/step
# Epoch 35/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 35 - MAE: 5.248502
# 285/285 - 5s - loss: 3.1895 - 5s/epoch - 17ms/step
# Epoch 36/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 36 - MAE: 5.224044
# 285/285 - 5s - loss: 3.0651 - 5s/epoch - 16ms/step
# Epoch 37/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 37 - MAE: 5.192873
# 285/285 - 5s - loss: 3.0398 - 5s/epoch - 18ms/step
# Epoch 38/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 38 - MAE: 5.193318
# 285/285 - 5s - loss: 3.0096 - 5s/epoch - 17ms/step
# Epoch 39/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 39 - MAE: 5.468038
# 285/285 - 5s - loss: 3.0266 - 5s/epoch - 17ms/step
# Epoch 40/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 40 - MAE: 5.224124
# 285/285 - 5s - loss: 2.8775 - 5s/epoch - 18ms/step
# Epoch 41/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 41 - MAE: 5.217867
# 285/285 - 5s - loss: 2.8143 - 5s/epoch - 18ms/step
# Epoch 42/50
# 142/142 [==============================] - 1s 7ms/step
# Epoch 42 - MAE: 5.205290
# 285/285 - 6s - loss: 2.7963 - 6s/epoch - 20ms/step
# Epoch 43/50
# 142/142 [==============================] - 1s 9ms/step
# Epoch 43 - MAE: 5.305953
# 285/285 - 7s - loss: 2.7252 - 7s/epoch - 24ms/step
# Epoch 44/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 44 - MAE: 5.351231
# 285/285 - 6s - loss: 2.7280 - 6s/epoch - 20ms/step
# Epoch 45/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 45 - MAE: 5.232550
# 285/285 - 5s - loss: 2.6647 - 5s/epoch - 17ms/step
# Epoch 46/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 46 - MAE: 5.320342
# 285/285 - 5s - loss: 2.6486 - 5s/epoch - 18ms/step
# Epoch 47/50
# 142/142 [==============================] - 1s 6ms/step
# Epoch 47 - MAE: 5.216908
# 285/285 - 4s - loss: 2.6515 - 4s/epoch - 15ms/step
# Epoch 48/50
# 142/142 [==============================] - 1s 5ms/step
# Epoch 48 - MAE: 5.239999
# 285/285 - 4s - loss: 2.5828 - 4s/epoch - 15ms/step
# Epoch 49/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 49 - MAE: 5.039530
# 285/285 - 4s - loss: 2.5724 - 4s/epoch - 12ms/step
# Epoch 50/50
# 142/142 [==============================] - 1s 4ms/step
# Epoch 50 - MAE: 5.169574
# 285/285 - 3s - loss: 2.5660 - 3s/epoch - 12ms/step
# 142/142 [==============================] - 1s 4ms/step

# %%
# Plot R-squared per epoch
plt.figure(figsize=(24, 6))

plt.subplot(1, 2, 1)
plt.plot(np.arange(1, 51), callback.mae_scores, marker='o', linestyle='-', color='r', label='Raw')
plt.plot(np.arange(1, 51), callback2.mae_scores, marker='o', linestyle='-', color='g', label='StandardScaler')
plt.plot(np.arange(1, 51), callback3.mae_scores, marker='o', linestyle='-', color='b', label='MinMaxScaler')
plt.plot(np.arange(1, 51), callback4.mae_scores, marker='o', linestyle='-', color='orange', label='RobustScaler')
plt.title('BiLSTM Mean Absolute Error (MAE)')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.grid(True)

plt.legend()

plt.show()
